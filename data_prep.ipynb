# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.corpus import stopwords
import re
import json 
import pandas as pd
# Download necessary NLTK data (only needed once)
nltk.download('vader_lexicon')
nltk.download('stopwords')

# Initialize VADER sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# Function to clean text and remove stop words
def clean_text(text):
    # Check if text is a string and not None
    if isinstance(text, str):
        # Remove special characters and numbers
        text = re.sub(r'[^a-zA-Z\s]', '', text, re.I|re.A)

        # Convert to lowercase
        text = text.lower()
        
        # Remove stop words
        stop_words = set(stopwords.words('english'))
        words = text.split()
        words = [w for w in words if not w in stop_words]
        text = " ".join(words)

        return text
    else:
        # Handle None or non-string values by returning an empty string or a placeholder
        return "" # or any suitable placeholder


json_file = "msft_stock_news.json"

# Open and load JSON file
with open(json_file, "r", encoding="utf-8") as file:
    try:
        data = json.load(file)  # Load JSON data
    except json.JSONDecodeError as e:
        print(f"Error loading JSON: {e}")
        data = []

# Convert JSON data to a DataFrame
df = pd.DataFrame(data)


# Apply the cleaning function to the 'text' column
df['cleaned_text'] = df['text'].apply(clean_text)

# Create a function to assign sentiment labels based on sentiment score
def assign_sentiment_label(score):
    if score >= 0.05:
        return "positive"
    elif score <= -0.05:
        return "negative"
    else:
        return "neutral"


# Function to calculate sentiment score
def get_sentiment_score(text):
    scores = analyzer.polarity_scores(text)
    return scores['compound']

# Calculate sentiment scores for cleaned text and store it in the 'sentiment' column
df['sentiment_score'] = df['cleaned_text'].apply(get_sentiment_score)
# Apply the function to create the 'sentiment_label' column
df['sentiment_label'] = df['sentiment_score'].apply(assign_sentiment_label)

# Ensure 'publishedDate' is datetime
df['publishedDate'] = pd.to_datetime(df['publishedDate'])

# Sort by symbol and time
df = df.sort_values(['symbol', 'publishedDate'])

# Set the index to publishedDate for rolling window
df.set_index('publishedDate', inplace=True)

df.head(2)
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\shekh\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\shekh\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                     symbol                                            title  \
# publishedDate
# 2019-04-16 17:52:00   MSFT  Microsoft launches $250 Xbox with no disc drive
# 2019-04-17 14:43:50   MSFT   Why Microsoft Remains A Better Buy Over Amazon
#
#                                                                  image  \
# publishedDate
# 2019-04-16 17:52:00  https://images.financialmodelingprep.com/news/...
# 2019-04-17 14:43:50  https://images.financialmodelingprep.com/news/...
#
#                                  site  \
# publishedDate
# 2019-04-16 17:52:00          cnbc.com
# 2019-04-17 14:43:50  seekingalpha.com
#
#                                                                   text  \
# publishedDate
# 2019-04-16 17:52:00  Microsoft launches $250 Xbox console with no d...
# 2019-04-17 14:43:50  Microsoft's valuation is reasonable given its ...
#
#                                                                    url  \
# publishedDate
# 2019-04-16 17:52:00  https://www.cnbc.com/2019/04/16/microsoft-250-...
# 2019-04-17 14:43:50  https://seekingalpha.com/article/4255018-micro...
#
#                                                           cleaned_text  \
# publishedDate
# 2019-04-16 17:52:00         microsoft launches xbox console disc drive
# 2019-04-17 14:43:50  microsofts valuation reasonable given historic...
#
#                      sentiment_score sentiment_label
# publishedDate
# 2019-04-16 17:52:00           0.0000         neutral
# 2019-04-17 14:43:50          -0.0516        negative

# %%
# Assuming 'publishedDate' is already set as index and is datetime
# (as shown in your screenshot)

# Calculate rolling 24-hour news count per symbol
df['news_count_last_24h'] = (
    df.groupby('symbol')['title']
    .rolling('24h').count()
    .reset_index(level=0, drop=True)
)

# Average sentiment score over last 24 hours
df['average_sentiment_last_24h'] = (
    df.groupby('symbol')['sentiment_score']
    .rolling('24h').mean()
    .reset_index(level=0, drop=True)
)

# Sentiment volatility over last 24 hours
df['news_volatility_impact'] = (
    df.groupby('symbol')['sentiment_score']
    .rolling('24h').std()
    .reset_index(level=0, drop=True)
)


df = df.reset_index()

# %%
# Out:
#            publishedDate symbol  \
# 0    2019-04-16 17:52:00   MSFT
# 1    2019-04-17 14:43:50   MSFT
# 2    2019-04-18 12:51:00   MSFT
# 3    2019-04-19 10:10:09   MSFT
# 4    2019-04-21 12:20:00   MSFT
# ...                  ...    ...
# 1435 2025-04-04 22:08:09   MSFT
# 1436 2025-04-05 08:05:00   MSFT
# 1437 2025-04-05 08:56:45   MSFT
# 1438 2025-04-06 07:00:00   MSFT
# 1439 2025-04-06 07:30:00   MSFT
#
#                                                   title  \
# 0       Microsoft launches $250 Xbox with no disc drive
# 1        Why Microsoft Remains A Better Buy Over Amazon
# 2     Microsoft acquires Express Logic to help its p...
# 3     Can Microsoft (MSFT) Keep the Earnings Surpris...
# 4     Microsoft Makes an IoT Push With a New Acquisi...
# ...                                                 ...
# 1435  Microsoft AI CEO's remarks interrupted by pro-...
# 1436  6 Dividend Growth Stocks I'm Buying As Tariffs...
# 1437  Microsoft: A Defensive Buy In An Uncertain Tar...
# 1438  3 Beaten-Down Tech Stocks to Buy That Have Rai...
# 1439  5 Brilliant AI Stocks That Billionaire Chase C...
#
#                                                   image              site  \
# 0     https://images.financialmodelingprep.com/news/...          cnbc.com
# 1     https://images.financialmodelingprep.com/news/...  seekingalpha.com
# 2     https://images.financialmodelingprep.com/news/...          cnbc.com
# 3     https://images.financialmodelingprep.com/news/...         zacks.com
# 4     https://images.financialmodelingprep.com/news/...          fool.com
# ...                                                 ...               ...
# 1435  https://images.financialmodelingprep.com/news/...       reuters.com
# 1436  https://images.financialmodelingprep.com/news/...  seekingalpha.com
# 1437  https://images.financialmodelingprep.com/news/...  seekingalpha.com
# 1438  https://images.financialmodelingprep.com/news/...          fool.com
# 1439  https://images.financialmodelingprep.com/news/...          fool.com
#
#                                                    text  \
# 0     Microsoft launches $250 Xbox console with no d...
# 1     Microsoft's valuation is reasonable given its ...
# 2     Express Logic says it has 6.2 billion deployme...
# 3     Microsoft (MSFT) has an impressive earnings su...
# 4     What is Express Logic, and why did Microsoft j...
# ...                                                 ...
# 1435  Microsoft AI CEO Mustafa Suleyman's remarks we...
# 1436  President Trump's tariffs are not negotiating ...
# 1437  Microsoft remains a defensive buy due to its d...
# 1438  Technology has become the single most importan...
# 1439  Looking at what successful hedge fund managers...
#
#                                                     url  \
# 0     https://www.cnbc.com/2019/04/16/microsoft-250-...
# 1     https://seekingalpha.com/article/4255018-micro...
# 2     https://www.cnbc.com/2019/04/18/microsoft-acqu...
# 3     https://www.zacks.com/stock/news/389007/can-mi...
# 4     https://www.fool.com/investing/2019/04/21/micr...
# ...                                                 ...
# 1435  https://www.reuters.com/world/us/microsoft-ai-...
# 1436  https://seekingalpha.com/article/4772932-6-div...
# 1437  https://seekingalpha.com/article/4773187-micro...
# 1438  https://www.fool.com/investing/2025/04/06/3-be...
# 1439  https://www.fool.com/investing/2025/04/06/5-br...
#
#                                            cleaned_text  sentiment_score  \
# 0            microsoft launches xbox console disc drive           0.0000
# 1     microsofts valuation reasonable given historic...          -0.0516
# 2     express logic says billion deployments threadx...           0.0000
# 3     microsoft msft impressive earnings surprise hi...           0.6597
# 4                           express logic microsoft buy           0.0000
# ...                                                 ...              ...
# 1435  microsoft ai ceo mustafa suleymans remarks int...          -0.6124
# 1436  president trumps tariffs negotiating tactics p...          -0.5267
# 1437  microsoft remains defensive buy due diversifie...           0.8646
# 1438  technology become single important sector us s...           0.2023
# 1439  looking successful hedge fund managers buy hol...           0.8360
#
#      sentiment_label  news_count_last_24h  average_sentiment_last_24h  \
# 0            neutral                  1.0                    0.000000
# 1           negative                  2.0                   -0.025800
# 2            neutral                  2.0                   -0.025800
# 3           positive                  2.0                    0.329850
# 4            neutral                  1.0                    0.000000
# ...              ...                  ...                         ...
# 1435        negative                 16.0                    0.268288
# 1436        negative                 17.0                    0.221524
# 1437        positive                 17.0                    0.264853
# 1438        positive                  3.0                    0.180067
# 1439        positive                  4.0                    0.344050
#
#       news_volatility_impact
# 0                        NaN
# 1                   0.036487
# 2                   0.036487
# 3                   0.466478
# 4                        NaN
# ...                      ...
# 1435                0.517354
# 1436                0.536753
# 1437                0.558040
# 1438                0.695916
# 1439                0.656071
#
# [1440 rows x 13 columns]
